# %% [markdown]
# #This project will detail the code necessary for creating a dashboard comparing GDP to Unemployment
# #Importing the pandas library and the bokeh data viz library

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# #Here the make_dashboard function is scriped resulting in a dashboard.
# #A html file will also be created so the dashboard can be shared

# %%
def make_dashboard(x, gdp_change, unemployment, title, file_name):
    output_file(file_name)
    p = figure(title=title, x_axis_label='year', y_axis_label='%')
    p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend="% GDP change")
    p.line(x.squeeze(), unemployment.squeeze(), line_width=4, legend="% unemployed")
    show (p)

# %% [markdown]
#      # The links to the data

# %%
links={'GDP':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv',\
       'unemployment':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_unemployment.csv'}

# %% [markdown]
#      #Using pandas to create the data frame.
#      #Using .head() to show the first 5 records.

# %%
df2= pd.read_csv ('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv')       
print (df2.head())
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1948          274.8         2020.0            -0.7            -0.6
# 1  1949          272.8         2008.9            10.0             8.7
# 2  1950          300.2         2184.0            15.7             8.0
# 3  1951          347.3         2360.0             5.9             4.1
# 4  1952          367.7         2456.1             6.0             4.7

# %% [markdown]
#     #Creating a dataframe unemployment

# %%
unemployment=pd.DataFrame(df['unemployment'])
print (unemployment)
# Out:
#     unemployment
# 0       3.750000
# 1       6.050000
# 2       5.208333
# 3       3.283333
# 4       3.025000
# ..           ...
# 64      8.075000
# 65      7.358333
# 66      6.158333
# 67      5.275000
# 68      4.875000
#
# [69 rows x 1 columns]

# %% [markdown]
#    #Creating a dataframe indicating unemployment levels > 8.5%

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()

df= pd.read_csv ('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_unemployment.csv')       
print (df[df['unemployment']>8.5])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#     date  unemployment
# 34  1982      9.708333
# 35  1983      9.600000
# 61  2009      9.283333
# 62  2010      9.608333
# 63  2011      8.933333

# %%
unemployment = pd.DataFrame()pd.read_csv ('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0

# %% [markdown]
#     #Here I am calling the make_dashboard function.
#     #The variables will be names the same as the function parameters.

# %% [markdown]
#     # Creating a new dataframe with a new column date assigned to x from the df of GDP data

# %%
x=pd.DataFrame(df['date'])       
print (x)
# Out:
#     date
# 0   1948
# 1   1949
# 2   1950
# 3   1951
# 4   1952
# ..   ...
# 64  2012
# 65  2013
# 66  2014
# 67  2015
# 68  2016
#
# [69 rows x 1 columns]

# %% [markdown]
#     #Creating a dataframe column 'change-current' called gdp_change

# %%
gdp_change=df2= pd.read_csv ('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv')       
print (df2[['change-current']])
# Out:
#     change-current
# 0             -0.7
# 1             10.0
# 2             15.7
# 3              5.9
# 4              6.0
# ..             ...
# 64             3.6
# 65             4.4
# 66             4.0
# 67             2.7
# 68             4.2
#
# [69 rows x 1 columns]

# %% [markdown]
#     # Assiging the dashboard title

# %%
title = ('Economic-Data')

# %% [markdown]
#     # The following will invoke the dashboard.
#     # It will result in a .html....'index.html

# %%
file_name = ("index.html")

# %%
title='Economic-Data'
file_name= "index.html"

make_dashboard(x=x, gdp_change=gdp_change, unemployment=unemployment, title=title, file_name=file_name)
output_file(file_name)
p = figure(title=title, x_axis_label='Year', y_axis_label='%')
p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend_label="% GDP change")
p.line(x.squeeze(), unemployment.squeeze(), color="steelblue",line_width=4, legend_label="% Unemployed")
show(p)
